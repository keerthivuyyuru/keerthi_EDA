# %% [markdown]
# **Data Transformation Techniques**
# - Generally used for to convert Normal distribution
# - Because all statistical math analysis by assumption Data follows Normal distribution
# - It is also avoid skew ness also
# - We have some important transformation
#     - Log transformation
#     - Exponential transformation
#     - Reciprocal transformation
#     - Square root transformation
#     - Power transformaton

# %% [markdown]
# $Step − 1$

# %% [markdown]
# **Read the required packages**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $Step − 2$

# %% [markdown]
# **Read the data**

# %% [markdown]
# $Exponential$ − $data$

# %%
exp_data=np.random.exponential(size=10000)
exp_data[:10]


# We are consider exponential data set with random 1k observations
# using numpy package
# Out:
# array([1.98308713, 0.06898529, 0.57160662, 1.38011481, 0.23298374,
#        0.29605716, 2.48953809, 4.40037871, 0.4674332 , 1.18073873])

# %%
plt.hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# $Norm$ − $data$

# %%
norm_data=np.random.normal(size=1000)
plt.hist(norm_data)
# Out:
# (array([  1.,   1.,  13.,  38., 187., 297., 285., 128.,  39.,  11.]),
#  array([-4.56156564, -3.79246286, -3.02336009, -2.25425732, -1.48515454,
#         -0.71605177,  0.05305101,  0.82215378,  1.59125655,  2.36035933,
#          3.1294621 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# $Step − 3$

# %% [markdown]
# **Log Transformaton**
#
# - np.log is used for log transformation
# - Generally log transformation will not convert data into normal
# - It avoids skew ness
# - np.log means natural logorithm base=e

# %%
x=2
import numpy as np
np.log(2)
# Out:
# 0.6931471805599453

# %%
log_data=np.log(exp_data)
log_data[:10]
# Out:
# array([ 0.68465479, -2.67386197, -0.55930425,  0.32216669, -1.45678663,
#        -1.21720272,  0.91209719,  1.48169061, -0.76049882,  0.16614029])

# %%
exp_data[:10]
# Out:
# array([1.98308713, 0.06898529, 0.57160662, 1.38011481, 0.23298374,
#        0.29605716, 2.48953809, 4.40037871, 0.4674332 , 1.18073873])

# %%
plt.hist(log_data,bins=40,label='Log data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,bins=40,label='Exponential')

plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=40,label='Log Transformation')

plt.legend()
plt.show()

# %% [markdown]
# $Step − 4$

# %% [markdown]
# **Reciprocal transformation**
#
# - Reciprocal transformation fails when data has zero value

# %%
# Take the exponential data
# rec_data= 1/exp_data
# plot the histogram and check it

# %%
x=3
rec_data= np.reciprocal(x)

# %%
exp_data,rec_data
# Out:
# (array([1.98308713, 0.06898529, 0.57160662, ..., 0.67154636, 1.30030043,
#         1.50691738]),
#  0)

# %%
1/0.77
# Out:
# 1.2987012987012987

# %%
rec_data=np.reciprocal(exp_data)
plt.hist(rec_data,bins=40,label='Reciprocal Data')
plt.legend()
plt.show()

# %%
exp_data[:2]
# Out:
# array([1.98308713, 0.06898529])

# %%
1/1.687,1/0.88
# Out:
# (0.5927682276229994, 1.1363636363636365)
