# %% [markdown]
# **Reading the Csv file**

# %% [markdown]
# updating the file

# %%
a=2
b=4
a+b
# Out:
# 6

# %%
import pandas as pd # Dataframe operations
import numpy as np # Math operations
import matplotlib.pyplot as plt # Diagrams / plots
import seaborn as sns # Diagrams / plots

# %%
# pandas as pd:
# Pandas is a powerful Python library for data manipulation and analysis.
# It provides data structures and functions for working with structured or tabular data, such as dataframes, which are similar to tables in a relational database or Excel spreadsheet.
# Pandas allows you to read and write data from various file formats (e.g., CSV, Excel, SQL databases), manipulate and transform data, handle missing values, perform aggregations, and much more.

# %%
# import numpy as np # Math operations

# NumPy is a fundamental library for numerical computing in Python.
# It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays efficiently.
# NumPy is widely used for tasks such as numerical simulations, linear algebra operations, random number generation, and more.

# %%
# matplotlib.pyplot as plt

# Matplotlib is a plotting library for creating static, interactive, and animated visualizations in Python.
# It provides a wide range of plotting functions to create various types of plots, including line plots, scatter plots, bar charts, histograms, and more.
# Matplotlib allows for extensive customization of plot aesthetics, labels, titles, axes, legends, and annotations.

# %%
# seaborn as sns

# Seaborn is a statistical data visualization library built on top of Matplotlib.
# It provides a high-level interface for creating attractive and informative statistical graphics.
# Seaborn simplifies the process of creating complex plots by providing built-in support for visualizing relationships between variables, including scatter plots, pair plots, joint plots, box plots, violin plots, and more.
# Seaborn also offers advanced features for styling plots, including color palettes, themes, and visualizations of statistical models.

# %%
# data set name: visadataset
# read csv file : Comma separeated value
# extension : .csv
# you can read this using pandas package
# read excel file
# extension: .xlsx

# %%
# path
#file location+filename+extension
path=r"C:\Users\Keerthi\OneDrive\Documents\Full stack data science and ai\Datafiles\Visadataset.csv"
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\Keerthi\OneDrive\Documents\Full stack data science and ai\Datafiles\bank.csv"
pd.read_csv(path)
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
path=r"C:\Users\Keerthi\OneDrive\Documents\Full stack data science and ai\Datafiles\bank.csv"
pd.read_csv(path,
            sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ***Create dataframes using List***

# %%
name=['Ramesh','Suresh','Sathish']
age=[30,35,40]
name,age
# Out:
# (['Ramesh', 'Suresh', 'Sathish'], [30, 35, 40])

# %% [markdown]
# **Step-1**

# %%
pd.DataFrame() # make the dataframe
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ***step-2:provide data***

# %%
pd.DataFrame(zip(name,age))
# Out:
#          0   1
# 0   Ramesh  30
# 1   Suresh  35
# 2  Sathish  40

# %% [markdown]
# ***Step-3: provide columns***

# %%
#Provide columns
data=zip(name,age)
cols=['Name','Age']
pd.DataFrame(data,columns=cols)
#pd.DataFrame(zip(name,age),columns=['Name','Age'])
# Out:
#       Name  Age
# 0   Ramesh   30
# 1   Suresh   35
# 2  Sathish   40

# %% [markdown]
# ***Step-4:provide index***

# %%
data=zip(name,age)
cols=['Name','Age']
ind=['A','B','C']
pd.DataFrame(data,
columns=cols,
index=ind)
# Out:
#       Name  Age
# A   Ramesh   30
# B   Suresh   35
# C  Sathish   40

# %% [markdown]
# ***Step-5: Add new column***

# %%
name=['Ramesh','Suresh','Sathish']
age=[30,35,40]
data=zip(name,age)
cols=['Name','Age']
ind=['A','B','C']
df=pd.DataFrame(data,columns=cols,index=ind)
df
# Out:
#       Name  Age
# A   Ramesh   30
# B   Suresh   35
# C  Sathish   40

# %% [markdown]
# - if you want to add a new column df['new column']
# - you need to have a list which is having some elements
#   that elements need to equal to number of rows
# - city_names=['Hyd','Blr','Chennai']
# - df['city']=city_names

# %%
city_names=['Hyd','Blr','Chennai']
df['city']=city_names
df
# Out:
#       Name  Age     city
# A   Ramesh   30      Hyd
# B   Suresh   35      Blr
# C  Sathish   40  Chennai

# %% [markdown]
# ***Step-6:update the exsisting column***
# - if you want to create new column or update the old column both are same way

# %%
df['Name']=['Swamy','Asif','Sathwik']
df
# Out:
#       Name  Age     city
# A    Swamy   30      Hyd
# B     Asif   35      Blr
# C  Sathwik   40  Chennai

# %% [markdown]
# ***Step-7:drop the column***

# %%
df.drop('city', # column name
        axis=1, # Column
        inplace=True) # overwrite the same
df
# Out:
#       Name  Age
# A    Swamy   30
# B     Asif   35
# C  Sathwik   40

# %% [markdown]
# ***Step − 8:Drop rows***

# %% [markdown]
# -  In order to drop the column
#  -  We need to use drop method
#  - It takes 3 parameters
#
#         - drop column or row
#         - mention the column name
#         -  axis
#
#             - axis=1 reference as column
#             - axis=0 reference as row
#  - you want to create a new dataframe or
#  - you want overwrite the existing dataframe
#
#             - inplace= True

# %%
df.drop('C', # column name
    axis=0, # Column
    inplace=True) # overwrite the same
df
# Out:
#     Name  Age
# A  Swamy   30
# B   Asif   35

# %% [markdown]
# ***Step-9:save the dataframe***

# %%
df.to_csv("output.csv")
# while saving index consider as extra column
df.to_excel("output.xlsx")

# %%
# read output csv
pd.read_csv("output.csv")
# Out:
#   Unnamed: 0   Name  Age
# 0          A  Swamy   30
# 1          B   Asif   35

# %% [markdown]
# ***Step-10:Remove The Index***

# %%
df.to_csv("output.csv",index=False)

# %%
pd.read_csv("output.csv")
# Out:
#     Name  Age
# 0  Swamy   30
# 1   Asif   35

# %% [markdown]
# ## Creat dataframes using dictionary

# %%
d1={"NAME":['Ramesh','Suresh','Sathish'],
"AGE":[30,35,40]}
pd.DataFrame(d1)
# Out:
#       NAME  AGE
# 0   Ramesh   30
# 1   Suresh   35
# 2  Sathish   40
